# %%
import numpy as np
import matplotlib.pyplot as plt

mcmc_E_list = np.load("/home/sijingdu/BP/PBC/1D/MC/Results/1DLJ_occ_L=8_N_a=50_T=3.0_E_list.npy")

# %%
fig, ax = plt.subplots()
ax.plot(mcmc_E_list)
ax.set(xlabel='MC steps', ylabel='Energy',
       title='Energy vs MC steps')
ax.grid()
plt.show()
